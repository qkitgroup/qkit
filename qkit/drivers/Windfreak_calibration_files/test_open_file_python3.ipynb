# %%
import numpy as np

# %%
path = "C:\qkit\qkit\drivers\Windfreak_calibration_files\Windfreak_290_"
channelA = "ChannelA_calibration_with_freq_and_pow"
channelB = "ChannelB_calibration_with_freq_and_pow"

calma = "calibration_matrix_dBm"
piu = "power_intrinsic_units"
freq = "frequency_Hz"

# %%
calA = {
    calma: np.loadtxt(path + channelA + "_" + calma + ".txt"),
    piu: np.loadtxt(path + channelA + "_" + piu + ".txt"),
    freq: np.loadtxt(path + channelA + "_" + freq + ".txt")
}

calB = {
    calma: np.loadtxt(path + channelB + "_" + calma + ".txt"),
    piu: np.loadtxt(path + channelB + "_" + piu + ".txt"),
    freq: np.loadtxt(path + channelB + "_" + freq + ".txt")
}

# %%
np.save(path + channelA, calA)
np.save(path + channelB, calB)

# %%
calA
# Out:
# {'calibration_matrix_dBm': array([[-47.3771267 , -46.8469677 , -45.8647213 , ...,  18.16485405,
#           18.25229168,  18.3334074 ],
#         [-47.57851219, -46.9414959 , -45.9247036 , ...,  18.0190711 ,
#           18.10979986,  18.19446325],
#         [-47.34976196, -46.79801941, -45.66139221, ...,  17.80342817,
#           17.88102531,  17.9533577 ],
#         ...,
#         [-43.07057762, -40.98402977, -38.66814232, ...,  16.36506271,
#           16.40377522,  16.43335629],
#         [-43.14234162, -41.04264832, -38.63292695, ...,  16.25078964,
#           16.29356575,  16.31819439],
#         [-43.00127792, -40.89967727, -38.64312362, ...,  16.25500012,
#           16.28578187,  16.32050324]]),
#  'power_intrinsic_units': array([10000., 10700., 11400., 12100., 12800., 13500., 14200., 14900.,
#         15600., 16300., 17000., 17700., 18400., 19100., 19800., 20500.,
#         21200., 21900., 22600., 23300., 24000., 24700., 25400., 26100.,
# ...
