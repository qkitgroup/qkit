# %%
import dat_reader as dr

# %%
reload(dr)
# Out:
# ...
# <module 'dat_reader' from 'dat_reader.py'>

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dr.fit_data('162601_avg_T1_40us_avg.dat',fit_function='exp',save_pdf=True)
# Out:
# Reading file 162601_avg_T1_40us_avg.dat
# decay time: 9.1458816265
# plot saved:
#  162601_avg_T1_40us_avg_dr.png
# array([ 9.14588163, -0.19007125, -0.21181038])

# %%
dr.fit_data('233830_avg_hahn_avg.dat',fit_function='exp',save_pdf=True)
# Out:
# Reading file 233830_avg_hahn_avg.dat
# decay time: 5.08816694008
# plot saved:
#  233830_avg_hahn_avg_dr.png
# array([ 5.08816694,  0.11265981, -0.2925214 ])

# %%
dr.fit_data('144442_avg_z_calib_0.13mA_0.5_avg.dat',fit_function='sine',ps=[0.067,0.09,-1.03,6.4],save_pdf=True)
# Out:
# Reading file 144442_avg_z_calib_0.13mA_0.5_avg.dat
# plot saved:
#  144442_avg_z_calib_0.13mA_0.5_avg_dr.png
# array([ 0.06765122,  0.0937873 , -1.0381522 ,  6.40616255])
